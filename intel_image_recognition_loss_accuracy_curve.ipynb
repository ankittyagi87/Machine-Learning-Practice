# %%
import numpy as np
import matplotlib.pyplot as plt
loss = np.array([1.7904, 0.9788, 0.7066, 0.4267, 0.3026, 0.2098, 0.1552, 0.1167, 0.0939, 0.1114, 0.0888, 0.0777, 0.0599, 0.0706, 0.1093, 0.0621, 0.0508, 0.0522, 0.0454, 0.0350, 0.0628, 0.0656, 0.0561, 0.0941, 0.0706, 0.0427, 0.0379, 0.0393, 0.0299, 0.0234, 0.0480, 0.0363, 0.0434, 0.0292, 0.0358, 0.0459, 0.0243, 0.0299, 0.0206, 0.0354])
acc = np.array([0.4380, 0.6233, 0.7407, 0.8499, 0.9052, 0.9304, 0.9522, 0.9677, 0.9743, 0.9711, 0.9772, 0.9791, 0.9842, 0.9808, 0.9716, 0.9813, 0.9871, 0.9869, 0.9864, 0.9932, 0.9857, 0.9842, 0.9833, 0.9733, 0.9816, 0.9871, 0.9903, 0.9905, 0.9908, 0.9930, 0.9864, 0.9898, 0.9901, 0.9922, 0.9915, 0.9893, 0.9939, 0.9910, 0.9951, 0.9915])

# %%
epoch = np.array(range(1,41))
print(acc.shape)
print(epoch.shape)
# Out:
# (40,)
# (40,)

# %%
plt.plot(epoch,acc)

# %%
plt.plot(epoch, loss)
